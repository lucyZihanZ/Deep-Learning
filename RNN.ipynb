# %% [markdown]
# Part 1: Build a Recurrent Neural Networks
#
# Part 2: Build LSTM model based on Recurrent Neural Networks
#
# All models base on PyTorch not base on TensorFlow

# %%
# helper code from the course repository
# !git clone https://github.com/interactiveaudiolab/course-deep-learning.git
# install common pacakges used for deep learning
# !cd course-deep-learning/ && pip install -r requirements.txt
# Out:
# Cloning into 'course-deep-learning'...
# remote: Enumerating objects: 575, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 575 (delta 15), reused 19 (delta 8), pack-reused 547 (from 1)
# Receiving objects: 100% (575/575), 146.09 MiB | 15.77 MiB/s, done.
# Resolving deltas: 100% (303/303), done.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 57.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 61.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 34.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.6 MB/s eta 0:00:00
# ...

# %%
# %cd course-deep-learning/
# !wget https://download.pytorch.org/tutorial/data.zip
# !unzip data.zip
# Out:
# /content/course-deep-learning
# --2025-02-27 03:03:54--  https://download.pytorch.org/tutorial/data.zip
# Resolving download.pytorch.org (download.pytorch.org)... 99.86.38.72, 99.86.38.96, 99.86.38.106, ...
# Connecting to download.pytorch.org (download.pytorch.org)|99.86.38.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2882130 (2.7M) [application/zip]
# Saving to: ‘data.zip’
#
# data.zip            100%[===================>]   2.75M  --.-KB/s    in 0.04s
#
# 2025-02-27 03:03:54 (62.3 MB/s) - ‘data.zip’ saved [2882130/2882130]
#
# Archive:  data.zip
#    creating: data/
#   inflating: data/eng-fra.txt
#    creating: data/names/
#   inflating: data/names/Arabic.txt
#   inflating: data/names/Chinese.txt
#   inflating: data/names/Czech.txt
#   inflating: data/names/Dutch.txt
#   inflating: data/names/English.txt
#   inflating: data/names/French.txt
#   inflating: data/names/German.txt
#   inflating: data/names/Greek.txt
# ...

# %%
# a simple RNN model
class RNNCell(nn.Module):
  def __init__(self, input_size, hidden_size, output_size):
    super(RNNCell, self).__init__()
    self.hidden_size = hidden_size
# weight matrix (input, prev hidden layers) --> hidden states
    self.i2h = nn.Linear(input_size + hidden_size, hidden_size)
# hidden states -> output layers
    self.i2o = nn.Linear(input_size + hidden_size, output_size)
  def forward(self, input, hidden):
    if input.ndimension() >2: # make sure input is a batch form
      L, B, V, *_ = input.size()
      assert L ==1
      input = input.squeeze(0) # reduce to two dimension
    combined = torch.cat((input, hidden), -1)
    hidden = self.i2h(combined)
    output = self.i2o(combined)
    return output, hidden
